# %% [markdown]
# <a href="https://colab.research.google.com/github/joowop/Metaverse_AI_Project/blob/main/sam_ipynb%EC%9D%98_%EC%82%AC%EB%B3%B8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install git+https://github.com/facebookresearch/segment-anything.git
# Out:
# Collecting git+https://github.com/facebookresearch/segment-anything.git
#   Cloning https://github.com/facebookresearch/segment-anything.git to /tmp/pip-req-build-b5s1cveo
#   Running command git clone --filter=blob:none --quiet https://github.com/facebookresearch/segment-anything.git /tmp/pip-req-build-b5s1cveo
#   Resolved https://github.com/facebookresearch/segment-anything.git to commit 6fdee8f2727f4506cfbbe553e23b895e27956588
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: segment-anything
#   Building wheel for segment-anything (setup.py) ... done
#   Created wheel for segment-anything: filename=segment_anything-1.0-py3-none-any.whl size=36586 sha256=cbc4c18c9783fe0090f0fe717062762f55b560735644230523a009f7afcfd40c
#   Stored in directory: /tmp/pip-ephem-wheel-cache-ws8d0dtf/wheels/10/cf/59/9ccb2f0a1bcc81d4fbd0e501680b5d088d690c6cfbc02dc99d
# Successfully built segment-anything
# Installing collected packages: segment-anything
# Successfully installed segment-anything-1.0

# %%
# !pip install -q jupyter_bbox_widget roboflow dataclasses-json supervision
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 367.8/367.8 kB 6.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.6/57.6 kB 7.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.3/63.3 kB 7.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 155.3/155.3 kB 13.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.7/178.7 kB 12.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 7.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.8/67.8 kB 9.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 6.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.4/49.4 kB 5.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 16.1 MB/s eta 0:00:00
#   Building wheel for wget (setup.py) ... done

# %%
import os
os.mkdir('weights')

# %%
os.chdir('/content/weights')
# !pwd
# Out:
# /content/weights

# %%
# !wget -q https://dl.fbaipublicfiles.com/segment_anything/sam_vit_h_4b8939.pth

# %%
CHECKPOINT_PATH = ('/content/weights/sam_vit_h_4b8939.pth')

# %%
os.mkdir('/content/data')
os.chdir('/content/data')

# %%
# !wget -q https://media.roboflow.com/notebooks/examples/dog.jpeg

# %%
import torch

DEVICE = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
MODEL_TYPE = 'vit_h'

# %%
from segment_anything import sam_model_registry, SamAutomaticMaskGenerator, SamPredictor

sam = sam_model_registry[MODEL_TYPE](checkpoint=CHECKPOINT_PATH).to(device=DEVICE)
mask_generator = SamAutomaticMaskGenerator(sam)

# %%
import cv2
import supervision as sv

image_bgr = cv2.imread('/content/data/dog.jpeg')
image_rgb = cv2.cvtColor(image_bgr,cv2.COLOR_BGR2RGB)

sam_result = mask_generator.generate(image_rgb)

# %%
sam_result
# Out:
# [{'segmentation': array([[False, False, False, ...,  True, False, False],
#          [False, False, False, ...,  True, False, False],
#          [False, False, False, ...,  True, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 234889,
#   'bbox': [3, 0, 714, 552],
#   'predicted_iou': 1.0237175226211548,
#   'point_coords': [[168.75, 100.0]],
#   'stability_score': 0.9896397590637207,
#   'crop_box': [0, 0, 720, 1280]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 141019,
#   'bbox': [75, 252, 545, 670],
#   'predicted_iou': 1.021133303642273,
#   'point_coords': [[348.75, 580.0]],
#   'stability_score': 0.9711280465126038,
#   'crop_box': [0, 0, 720, 1280]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [ True,  True,  True, ..., False, False, False],
#          [ True,  True,  True, ..., False, False, False],
#          [ True,  True,  True, ..., False, False, False]]),
#   'area': 179795,
#   'bbox': [0, 672, 453, 607],
#   'predicted_iou': 1.0203702449798584,
#   'point_coords': [[258.75, 1020.0]],
#   'stability_score': 0.9823009967803955,
#   'crop_box': [0, 0, 720, 1280]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 44148,
#   'bbox': [567, 291, 152, 434],
#   'predicted_iou': 1.0115917921066284,
#   'point_coords': [[618.75, 340.0]],
#   'stability_score': 0.9742111563682556,
#   'crop_box': [0, 0, 720, 1280]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [ True,  True,  True, ..., False, False, False],
#          [ True,  True,  True, ..., False, False, False],
#          [ True,  True,  True, ..., False, False, False]]),
#   'area': 12584,
#   'bbox': [0, 1086, 101, 193],
#   'predicted_iou': 1.0109121799468994,
#   'point_coords': [[33.75, 1180.0]],
#   'stability_score': 0.9818511605262756,
#   'crop_box': [0, 0, 720, 1280]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 96970,
#   'bbox': [30, 661, 575, 618],
#   'predicted_iou': 1.0091562271118164,
#   'point_coords': [[573.75, 780.0]],
#   'stability_score': 0.9503352046012878,
#   'crop_box': [0, 0, 720, 1280]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 79646,
#   'bbox': [498, 783, 221, 496],
#   'predicted_iou': 1.004939079284668,
#   'point_coords': [[551.25, 1220.0]],
#   'stability_score': 0.9666617512702942,
#   'crop_box': [0, 0, 720, 1280]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 2367,
#   'bbox': [534, 1250, 124, 29],
#   'predicted_iou': 0.9996863603591919,
#   'point_coords': [[618.75, 1260.0]],
#   'stability_score': 0.9915789365768433,
#   'crop_box': [0, 0, 720, 1280]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 11494,
#   'bbox': [489, 614, 155, 231],
#   'predicted_iou': 0.9972618222236633,
#   'point_coords': [[528.75, 700.0]],
#   'stability_score': 0.9788296222686768,
#   'crop_box': [0, 0, 720, 1280]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 8563,
#   'bbox': [340, 462, 127, 100],
#   'predicted_iou': 0.996921181678772,
#   'point_coords': [[371.25, 540.0]],
#   'stability_score': 0.9879294633865356,
#   'crop_box': [0, 0, 720, 1280]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [ True,  True,  True, ..., False, False, False],
#          [ True,  True,  True, ..., False, False, False],
#          [ True,  True,  True, ..., False, False, False]]),
#   'area': 180659,
#   'bbox': [0, 397, 455, 882],
#   'predicted_iou': 0.9933710098266602,
#   'point_coords': [[393.75, 1060.0]],
#   'stability_score': 0.9754505753517151,
#   'crop_box': [0, 0, 720, 1280]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 79236,
#   'bbox': [376, 721, 342, 558],
#   'predicted_iou': 0.9909924268722534,
#   'point_coords': [[528.75, 1180.0]],
#   'stability_score': 0.9692315459251404,
#   'crop_box': [0, 0, 720, 1280]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 11350,
#   'bbox': [448, 396, 92, 216],
#   'predicted_iou': 0.9909425377845764,
#   'point_coords': [[461.25, 500.0]],
#   'stability_score': 0.9845455288887024,
#   'crop_box': [0, 0, 720, 1280]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 29236,
#   'bbox': [0, 358, 203, 213],
#   'predicted_iou': 0.989557147026062,
#   'point_coords': [[78.75, 540.0]],
#   'stability_score': 0.9838446974754333,
#   'crop_box': [0, 0, 720, 1280]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 1830,
#   'bbox': [411, 1150, 50, 105],
#   'predicted_iou': 0.9862177968025208,
#   'point_coords': [[416.25, 1220.0]],
#   'stability_score': 0.9689673781394958,
#   'crop_box': [0, 0, 720, 1280]},
#  {'segmentation': array([[False, False, False, ...,  True, False, False],
#          [False, False, False, ...,  True, False, False],
#          [False, False, False, ...,  True, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 237833,
#   'bbox': [0, 0, 718, 1272],
#   'predicted_iou': 0.9857496023178101,
#   'point_coords': [[573.75, 300.0]],
#   'stability_score': 0.9562122821807861,
#   'crop_box': [0, 0, 720, 1280]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 4873,
#   'bbox': [388, 296, 94, 80],
#   'predicted_iou': 0.9769560098648071,
#   'point_coords': [[416.25, 300.0]],
#   'stability_score': 0.9792935252189636,
#   'crop_box': [0, 0, 720, 1280]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 16367,
#   'bbox': [318, 642, 207, 586],
#   'predicted_iou': 0.974470317363739,
#   'point_coords': [[461.25, 1020.0]],
#   'stability_score': 0.9517327547073364,
#   'crop_box': [0, 0, 720, 1280]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 18308,
#   'bbox': [299, 561, 324, 667],
#   'predicted_iou': 0.970274806022644,
#   'point_coords': [[371.25, 780.0]],
#   'stability_score': 0.9634661674499512,
#   'crop_box': [0, 0, 720, 1280]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 3111,
#   'bbox': [541, 730, 64, 187],
#   'predicted_iou': 0.9697399735450745,
#   'point_coords': [[596.25, 780.0]],
#   'stability_score': 0.9717729091644287,
#   'crop_box': [0, 0, 720, 1280]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 17138,
#   'bbox': [542, 609, 177, 169],
#   'predicted_iou': 0.9697391986846924,
#   'point_coords': [[663.75, 620.0]],
#   'stability_score': 0.9772503972053528,
#   'crop_box': [0, 0, 720, 1280]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 3525,
#   'bbox': [615, 691, 84, 69],
#   'predicted_iou': 0.9693315029144287,
#   'point_coords': [[641.25, 700.0]],
#   'stability_score': 0.9631490707397461,
#   'crop_box': [0, 0, 720, 1280]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 2069,
#   'bbox': [570, 311, 120, 35],
#   'predicted_iou': 0.9664674997329712,
#   'point_coords': [[573.75, 340.0]],
#   'stability_score': 0.9765998125076294,
#   'crop_box': [0, 0, 720, 1280]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 276,
#   'bbox': [335, 1141, 18, 18],
#   'predicted_iou': 0.9661168456077576,
#   'point_coords': [[348.75, 1140.0]],
#   'stability_score': 0.9892086386680603,
#   'crop_box': [0, 0, 720, 1280]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 143045,
#   'bbox': [31, 251, 612, 917],
#   'predicted_iou': 0.964733362197876,
#   'point_coords': [[551.25, 780.0]],
#   'stability_score': 0.958185076713562,
#   'crop_box': [0, 0, 720, 1280]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 2523,
#   'bbox': [629, 735, 67, 50],
#   'predicted_iou': 0.9626332521438599,
#   'point_coords': [[641.25, 740.0]],
#   'stability_score': 0.9757433533668518,
#   'crop_box': [0, 0, 720, 1280]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 4699,
#   'bbox': [369, 1155, 90, 124],
#   'predicted_iou': 0.9618370532989502,
#   'point_coords': [[416.25, 1220.0]],
#   'stability_score': 0.9726890921592712,
#   'crop_box': [0, 0, 720, 1280]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 1320,
#   'bbox': [0, 593, 18, 79],
#   'predicted_iou': 0.9612442851066589,
#   'point_coords': [[11.25, 620.0]],
#   'stability_score': 0.9804804921150208,
#   'crop_box': [0, 0, 720, 1280]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 4055,
#   'bbox': [525, 556, 75, 68],
#   'predicted_iou': 0.9595595598220825,
#   'point_coords': [[573.75, 620.0]],
#   'stability_score': 0.9718378186225891,
#   'crop_box': [0, 0, 720, 1280]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 7617,
#   'bbox': [28, 693, 83, 182],
#   'predicted_iou': 0.9582258462905884,
#   'point_coords': [[56.25, 820.0]],
#   'stability_score': 0.9727107882499695,
#   'crop_box': [0, 0, 720, 1280]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 9316,
#   'bbox': [446, 1099, 86, 180],
#   'predicted_iou': 0.9567985534667969,
#   'point_coords': [[461.25, 1180.0]],
#   'stability_score': 0.9778178930282593,
#   'crop_box': [0, 0, 720, 1280]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 12532,
#   'bbox': [0, 471, 200, 227],
#   'predicted_iou': 0.9552014470100403,
#   'point_coords': [[123.75, 620.0]],
#   'stability_score': 0.9583626389503479,
#   'crop_box': [0, 0, 720, 1280]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 23544,
#   'bbox': [0, 471, 643, 373],
#   'predicted_iou': 0.9545689821243286,
#   'point_coords': [[146.25, 620.0]],
#   'stability_score': 0.9506571888923645,
#   'crop_box': [0, 0, 720, 1280]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 1029,
#   'bbox': [299, 290, 43, 31],
#   'predicted_iou': 0.9510395526885986,
#   'point_coords': [[303.75, 300.0]],
#   'stability_score': 0.9591643214225769,
#   'crop_box': [0, 0, 720, 1280]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 39735,
#   'bbox': [0, 358, 208, 348],
#   'predicted_iou': 0.9490032196044922,
#   'point_coords': [[56.25, 500.0]],
#   'stability_score': 0.9775221943855286,
#   'crop_box': [0, 0, 720, 1280]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 150,
#   'bbox': [673, 775, 16, 11],
#   'predicted_iou': 0.9487461447715759,
#   'point_coords': [[686.25, 780.0]],
#   'stability_score': 0.9671052694320679,
#   'crop_box': [0, 0, 720, 1280]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 1914,
#   'bbox': [0, 961, 17, 154],
#   'predicted_iou': 0.9459246397018433,
#   'point_coords': [[11.25, 1020.0]],
#   'stability_score': 0.9697436094284058,
#   'crop_box': [0, 0, 720, 1280]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 721,
#   'bbox': [571, 324, 44, 21],
#   'predicted_iou': 0.9454918503761292,
#   'point_coords': [[596.25, 340.0]],
#   'stability_score': 0.9807427525520325,
#   'crop_box': [0, 0, 720, 1280]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 11033,
#   'bbox': [207, 316, 100, 305],
#   'predicted_iou': 0.9439411163330078,
#   'point_coords': [[236.25, 540.0]],
#   'stability_score': 0.9620625376701355,
#   'crop_box': [0, 0, 720, 1280]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 381,
#   'bbox': [656, 456, 16, 23],
#   'predicted_iou': 0.9419973492622375,
#   'point_coords': [[663.75, 460.0]],
#   'stability_score': 0.9843342304229736,
#   'crop_box': [0, 0, 720, 1280]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 424,
#   'bbox': [606, 517, 18, 25],
#   'predicted_iou': 0.9419236779212952,
#   'point_coords': [[618.75, 540.0]],
#   'stability_score': 0.9582366347312927,
#   'crop_box': [0, 0, 720, 1280]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 7850,
#   'bbox': [16, 508, 133, 121],
#   'predicted_iou': 0.9412055611610413,
#   'point_coords': [[33.75, 580.0]],
#   'stability_score': 0.9632362127304077,
#   'crop_box': [0, 0, 720, 1280]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 294,
#   'bbox': [685, 975, 34, 11],
#   'predicted_iou': 0.9389158487319946,
#   'point_coords': [[708.75, 980.0]],
#   'stability_score': 0.9864864945411682,
#   'crop_box': [0, 0, 720, 1280]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 713,
#   'bbox': [304, 295, 34, 25],
#   'predicted_iou': 0.9386277794837952,
#   'point_coords': [[326.25, 300.0]],
#   'stability_score': 0.9818941354751587,
#   'crop_box': [0, 0, 720, 1280]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 2830,
#   'bbox': [366, 1216, 87, 63],
#   'predicted_iou': 0.9382625818252563,
#   'point_coords': [[416.25, 1260.0]],
#   'stability_score': 0.9600138068199158,
#   'crop_box': [0, 0, 720, 1280]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 1987,
#   'bbox': [410, 0, 62, 259],
#   'predicted_iou': 0.938018798828125,
#   'point_coords': [[416.25, 100.0]],
#   'stability_score': 0.9697120189666748,
#   'crop_box': [0, 0, 720, 1280]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 3627,
#   'bbox': [0, 655, 58, 89],
#   'predicted_iou': 0.9379690885543823,
#   'point_coords': [[33.75, 700.0]],
#   'stability_score': 0.977371871471405,
#   'crop_box': [0, 0, 720, 1280]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 2721,
#   'bbox': [195, 906, 54, 92],
#   'predicted_iou': 0.9361764788627625,
#   'point_coords': [[236.25, 980.0]],
#   'stability_score': 0.9635247588157654,
#   'crop_box': [0, 0, 720, 1280]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 1216,
#   'bbox': [650, 1034, 69, 25],
#   'predicted_iou': 0.9360014796257019,
#   'point_coords': [[686.25, 1060.0]],
#   'stability_score': 0.9698942303657532,
#   'crop_box': [0, 0, 720, 1280]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 304,
#   'bbox': [541, 588, 10, 34],
#   'predicted_iou': 0.9339123964309692,
#   'point_coords': [[551.25, 620.0]],
#   'stability_score': 0.9645161032676697,
#   'crop_box': [0, 0, 720, 1280]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 2131,
#   'bbox': [30, 0, 91, 32],
#   'predicted_iou': 0.9327309727668762,
#   'point_coords': [[101.25, 20.0]],
#   'stability_score': 0.9731481671333313,
#   'crop_box': [0, 0, 720, 1280]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 193,
#   'bbox': [412, 1049, 13, 16],
#   'predicted_iou': 0.9327259063720703,
#   'point_coords': [[416.25, 1060.0]],
#   'stability_score': 0.9845361113548279,
#   'crop_box': [0, 0, 720, 1280]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 831,
#   'bbox': [649, 803, 70, 19],
#   'predicted_iou': 0.9303597807884216,
#   'point_coords': [[708.75, 820.0]],
#   'stability_score': 0.9621301889419556,
#   'crop_box': [0, 0, 720, 1280]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 1183,
#   'bbox': [526, 560, 74, 22],
#   'predicted_iou': 0.925385057926178,
#   'point_coords': [[573.75, 580.0]],
#   'stability_score': 0.9618257284164429,
#   'crop_box': [0, 0, 720, 1280]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 7405,
#   'bbox': [84, 41, 97, 102],
#   'predicted_iou': 0.9221476316452026,
#   'point_coords': [[101.25, 60.0]],
#   'stability_score': 0.956131100654602,
#   'crop_box': [0, 0, 720, 1280]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 1949,
#   'bbox': [262, 491, 84, 85],
#   'predicted_iou': 0.9215516448020935,
#   'point_coords': [[303.75, 540.0]],
#   'stability_score': 0.9652392864227295,
#   'crop_box': [0, 0, 720, 1280]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 137,
#   'bbox': [358, 735, 12, 13],
#   'predicted_iou': 0.9207718372344971,
#   'point_coords': [[371.25, 740.0]],
#   'stability_score': 0.9784172773361206,
#   'crop_box': [0, 0, 720, 1280]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 360,
#   'bbox': [625, 890, 49, 9],
#   'predicted_iou': 0.9206079840660095,
#   'point_coords': [[641.25, 900.0]],
#   'stability_score': 0.9861878156661987,
#   'crop_box': [0, 0, 720, 1280]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 2721,
#   'bbox': [0, 1178, 71, 46],
#   'predicted_iou': 0.9189528822898865,
#   'point_coords': [[11.25, 1220.0]],
#   'stability_score': 0.9627755880355835,
#   'crop_box': [0, 0, 720, 1280]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 4987,
#   'bbox': [0, 593, 58, 151],
#   'predicted_iou': 0.9163187742233276,
#   'point_coords': [[33.75, 700.0]],
#   'stability_score': 0.9659944772720337,
#   'crop_box': [0, 0, 720, 1280]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 331,
#   'bbox': [603, 412, 17, 20],
#   'predicted_iou': 0.9140417575836182,
#   'point_coords': [[618.75, 420.0]],
#   'stability_score': 0.9646017551422119,
#   'crop_box': [0, 0, 720, 1280]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 2237,
#   'bbox': [20, 655, 38, 73],
#   'predicted_iou': 0.9035422801971436,
#   'point_coords': [[33.75, 660.0]],
#   'stability_score': 0.9735333323478699,
#   'crop_box': [0, 0, 720, 1280]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 1945,
#   'bbox': [0, 489, 45, 58],
#   'predicted_iou': 0.9025495648384094,
#   'point_coords': [[11.25, 500.0]],
#   'stability_score': 0.9591939449310303,
#   'crop_box': [0, 0, 720, 1280]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 377,
#   'bbox': [660, 569, 18, 21],
#   'predicted_iou': 0.8962156176567078,
#   'point_coords': [[663.75, 580.0]],
#   'stability_score': 0.9580052495002747,
#   'crop_box': [0, 0, 720, 1280]}]

# %%
mask_annotator = sv.MaskAnnotator()
detections = sv.Detections.from_sam(sam_result)
annotated_image = mask_annotator.annotate(image_bgr, detections)

# %%
from google.colab.patches import cv2_imshow
cv2_imshow(annotated_image)
# Out:
# <PIL.Image.Image image mode=RGB size=720x1280>

# %%
import cv2
from segment_anything import SamPredictor
import numpy as np

mask_predictor = SamPredictor(sam)

image_bgr = cv2.imread('/content/data/dog.jpeg')
image_rgb = cv2.cvtColor(image_bgr, cv2.COLOR_BGR2RGB)
mask_predictor.set_image(image_rgb)

box = np.array([70, 247, 626, 926])
masks, scores, logits = mask_predictor.predict(
    box=box,
    multimask_output=True
)

# %%
masks
# Out:
# array([[[False, False, False, ..., False, False, False],
#         [False, False, False, ..., False, False, False],
#         [False, False, False, ..., False, False, False],
#         ...,
#         [False, False, False, ..., False, False, False],
#         [False, False, False, ..., False, False, False],
#         [False, False, False, ..., False, False, False]],
#
#        [[False, False, False, ..., False, False, False],
#         [False, False, False, ..., False, False, False],
#         [False, False, False, ..., False, False, False],
#         ...,
#         [False, False, False, ..., False, False, False],
#         [False, False, False, ..., False, False, False],
#         [False, False, False, ..., False, False, False]],
#
#        [[False, False, False, ..., False, False, False],
#         [False, False, False, ..., False, False, False],
#         [False, False, False, ..., False, False, False],
#         ...,
#         [False, False, False, ..., False, False, False],
#         [False, False, False, ..., False, False, False],
#         [False, False, False, ..., False, False, False]]])

# %%
import supervision as sv

sv.plot_images_grid(
    images=masks,
    grid_size=(1, 4),
    size=(16, 4)
)

# %%
box_annotator = sv.BoxAnnotator(color=sv.Color.red())
mask_annotator = sv.MaskAnnotator(color=sv.Color.red())

detections = sv.Detections(
    xyxy=sv.mask_to_xyxy(masks=masks),
    mask=masks
)
detections = detections[detections.area == np.max(detections.area)]

source_image = box_annotator.annotate(scene=image_bgr.copy(), detections=detections, skip_label=True)
segmented_image = mask_annotator.annotate(scene=image_bgr.copy(), detections=detections)

sv.plot_images_grid(
    images=[source_image, segmented_image],
    grid_size=(1, 2),
    titles=['source image', 'segmented image']
)

# %%
def show_anns(anns, axes=None):
    if len(anns) == 0:
        return
    if axes:
        ax = axes
    else:
        ax = plt.gca()
        ax.set_autoscale_on(False)
    sorted_anns = sorted(anns, key=(lambda x: x['area']), reverse=True)
    polygons = []
    color = []
    for ann in sorted_anns:
        m = ann['segmentation']
        img = np.ones((m.shape[0], m.shape[1], 3))
        color_mask = np.random.random((1, 3)).tolist()[0]
        for i in range(3):
            img[:,:,i] = color_mask[i]
        ax.imshow(np.dstack((img, m*0.5)))

def show_mask(mask, ax, random_color=False):
    if random_color:
        color = np.concatenate([np.random.random(3), np.array([0.6])], axis=0)
    else:
        color = np.array([30/255, 144/255, 255/255, 0.6])
    h, w = mask.shape[-2:]
    mask_image = mask.reshape(h, w, 1) * color.reshape(1, 1, -1)
    ax.imshow(mask_image)


def show_points(coords, labels, ax, marker_size=375):
    pos_points = coords[labels==1]
    neg_points = coords[labels==0]
    ax.scatter(pos_points[:, 0], pos_points[:, 1], color='green', marker='*', s=marker_size, edgecolor='white', linewidth=1.25)
    ax.scatter(neg_points[:, 0], neg_points[:, 1], color='red', marker='*', s=marker_size, edgecolor='white', linewidth=1.25)


def show_box(box, ax):
    x0, y0 = box[0], box[1]
    w, h = box[2] - box[0], box[3] - box[1]
    ax.add_patch(plt.Rectangle((x0, y0), w, h, edgecolor='green', facecolor=(0,0,0,0), lw=2))

# %%
import matplotlib.pyplot as plt

image_path = '/content/data/dog.jpeg'
image_array = cv2.cvtColor(cv2.imread(image_path), cv2.COLOR_BGR2RGB)
mask_predictor.set_image(image_array)

input_point = np.array([[120, 400]])
input_label = np.array([1])

plt.imshow(image_array)
show_points(input_point, input_label, plt.gca())
plt.axis('on')
plt.show()



masks, scores, logits = mask_predictor.predict(
    point_coords=input_point,
    point_labels=input_label,
    multimask_output=True,
)

for i, (mask, score) in enumerate(zip(masks, scores)):
#     plt.figure(figsize=(10,10))
    plt.imshow(image_array)
    show_mask(mask, plt.gca())
    show_points(input_point, input_label, plt.gca())
    plt.title(f"Mask {i+1}, Score: {score:.3f}", fontsize=18)
    plt.show()
